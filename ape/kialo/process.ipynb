# %%
import sys, time, json, re
from anytree import Node, RenderTree
from anytree.exporter import JsonExporter
from anytree import Node, RenderTree

sys.setrecursionlimit(100000)

# %%
def group_arguments(tableau):
    argGroup = tableau[0]
    i = 1

    while True:

        if i > len(tableau) - 1:
            return [argGroup]

        stance = re.search(r"(Con|Pro)(?::)", tableau[i])
        if stance == None:
            argGroup = argGroup + " " + tableau[i]
            i+=1
        else:
            return [argGroup] + group_arguments(tableau[i:])

# %%
def rawKialo2Json(input_file):
    with open(input_file, 'r') as fi:
        lines = []
        for line in fi:
            if line.startswith("Sources:"):
                break
            lines.append(line.strip())

        lines = [x for x in lines if x]

        # list containing each parsed comment
        result = []

        # we remove the first two lines of the text
        # as we don't need the header
        header = []
        for line in range(0, 4):
            header.append(lines.pop(0))

        subject = header[1]

        lines = group_arguments(lines)

        ##                                            ##
        ##                 REGEDITS                   ##
        ##                                            ##
        # iterate every row in the text file
        counter = 1
        for line in lines:

            # find the tree position the comment is in
            tree =  re.search(r"^(\d{1,}.)+", line)

            # find if the comment is Pro or Con
            stance = re.search(r"(Con|Pro)(?::)", line)

            # find the text of the comment
            content = re.search(r"((Con|Pro)(?::\s))(.*)", line)

            # define the hierarchy of the current comment
            # which is based on the tree structure

            parsed = re.findall(r"(\d{1,}(?=\.))+", tree.group())
            level = len(parsed)-1

            # make a dictionary with the single entry
            # and put it at the end of the list
            result.append({
                "Tree": tree.group(),
                "Level": level,
                "Stance": stance.group(1),
                "ToneInput": content.group(3),
                "node_id":subject.replace(" ","_")+"_"+str(counter)
            })

            counter+=1
        
        to_write = json.dumps(result, sort_keys=True, indent=4, separators=(',', ': '))

    trees = [x["Tree"] for x in result]
    trees = ['1.'] + trees

    resultAsDict = { x["Tree"]: x for x in result }

    id2Node = {}


    for idNode in trees:
        if idNode == '1.':
            id2Node[idNode] = Node(idNode, node_id=-1)
        else:
            parentId = idNode[:idNode[:-1].rfind(".")+1]
            id2Node[idNode] = Node(idNode,
                                    parent=id2Node[parentId],
                                    tree=resultAsDict[idNode]["Tree"], 
                                    level=resultAsDict[idNode]["Level"], 
                                    stance=resultAsDict[idNode]["Stance"], 
                                    toneInput=resultAsDict[idNode]["ToneInput"], 
                                    subject=subject,
                                    node_id=resultAsDict[idNode]["node_id"]
    )

    return id2Node

# %%
def argumentTree2argumentPairTree(node, domains):    
    pairs = []
    
    if len(node.children) == 0:
        return pairs
    elif node.children != None:
        for child in node.children:
            if node.name != "1.":
                pair = {
                    "topArgument"       :   node.toneInput,
                    "subArgument"       :   child.toneInput,
                    "subject"           :   child.subject,
                    "subArgumentLevel"  :   child.level,
                    "domain"            :   domains
                }
                if child.stance == "Con":
                    pair["isAttack"] = True
                    pair["isSupport"] = False
                else:
                    pair["isAttack"] = False
                    pair["isSupport"] = True
                pairs.append(pair)

            pairs += argumentTree2argumentPairTree(child, domains)
        
    return pairs

# %%
import pandas as pd

kialoUrlIds = pd.read_csv("../../data/kialo/kialo-url-ids.csv", index_col=0)
pairs = []

for i, x in kialoUrlIds.iterrows():
  try:
    d = x.tags
    kialoUrlId = x.kialoUrlId

    # print(x)

    t = rawKialo2Json("../../data/kialo/debates/en/"+ kialoUrlId +".txt")
    pairs = pairs + argumentTree2argumentPairTree(t['1.'], d)
  except:
    continue

# %%
pairs
# Out:
# [{'topArgument': 'Football is very popular and a critical part of many communities.',
#   'subArgument': 'The institution of American football alienates many communities.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 2,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The institution of American football alienates many communities.',
#   'subArgument': 'The institution of American football promotes problematic gender roles, alienating people who do not conform to them.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'The institution of American football promotes problematic gender roles, alienating people who do not conform to them.',
#   'subArgument': 'American football promotes a form of masculinity [1] that is harmful.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'American football promotes a form of masculinity [1] that is harmful.',
#   'subArgument': 'Jim Harbaugh [2] and Rush Limbaugh [3] argue that American football is the last hope for keeping American men tough.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 5,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Jim Harbaugh [2] and Rush Limbaugh [3] argue that American football is the last hope for keeping American men tough.',
#   'subArgument': 'A player formerly coached by Jim Harbauge [4] claims that Harbauge was unreasonable and often pushed players too hard.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 6,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'American football promotes a form of masculinity [1] that is harmful.',
#   'subArgument': 'The toxic masculinity [5] promoted by American football often leads players to take unnecessary risks.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 5,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'American football promotes a form of masculinity [1] that is harmful.',
#   'subArgument': 'The NFL has a long history of homophobia [6].',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 5,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'The institution of American football alienates many communities.',
#   'subArgument': 'The institution of American football alienates people from many cultures through cultural appropriation [7].',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'The institution of American football alienates people from many cultures through cultural appropriation [7].',
#   'subArgument': 'Several NFL team mascots, chants, and celebrations appropriate Native American [8] culture.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Several NFL team mascots, chants, and celebrations appropriate Native American [8] culture.',
#   'subArgument': 'The Kansas City Chiefs [9] begin their games with chants, dances, and face paint appropriated from Native American culture.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 5,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'The institution of American football alienates people from many cultures through cultural appropriation [7].',
#   'subArgument': 'Many of the names and mascots of college football organizations appropriate [10] indigenous cultures.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'The institution of American football alienates people from many cultures through cultural appropriation [7].',
#   'subArgument': 'Youth football [11] organizations regularly base their names and mascots on indigenous cultures.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'The institution of American football alienates people from many cultures through cultural appropriation [7].',
#   'subArgument': 'Cultural appropriation and alienation are not unique [12] to American football.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The institution of American football alienates people from many cultures through cultural appropriation [7].',
#   'subArgument': 'Cultural appropriation [13] should not be seen as problematic. Popular activities have always involved borrowing and adapting elements of other cultures.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Cultural appropriation [13] should not be seen as problematic. Popular activities have always involved borrowing and adapting elements of other cultures.',
#   'subArgument': 'Cultural appropriation [14] is problematic when a dominant culture appropriates elements of a vulnerable minority culture.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 5,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Cultural appropriation [14] is problematic when a dominant culture appropriates elements of a vulnerable minority culture.',
#   'subArgument': 'Cultural appropriation [15] in American football typically involves the dominant American culture appropriating elements of vulnerable indigenous cultures.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 6,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'The institution of American football alienates many communities.',
#   'subArgument': 'The NCAA has an Office of Inclusion [16], which promotes diversity and inclusion in college athletics programs.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The NCAA has an Office of Inclusion [16], which promotes diversity and inclusion in college athletics programs.',
#   'subArgument': 'The NCAA diversity and inclusion initiatives were started relatively recently [17], which suggests that the changes are still ongoing.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The institution of American football alienates many communities.',
#   'subArgument': 'The NFL promotes diversity and inclusion by partnering with the You Can Play [18] organization, which promotes LGBTQ+ inclusion and representation in sports.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The NFL promotes diversity and inclusion by partnering with the You Can Play [18] organization, which promotes LGBTQ+ inclusion and representation in sports.',
#   'subArgument': 'Many of the inclusion efforts of the NFL were enacted as recently as May 2020 [19], which suggests that more change is necessary.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Football is very popular and a critical part of many communities.',
#   'subArgument': 'College football programs contribute significantly to the identity and brand of universities in the United States.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 2,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'College football programs contribute significantly to the identity and brand of universities in the United States.',
#   'subArgument': 'A lot of the typical American college experience [20] is built around the college football team.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'A lot of the typical American college experience [20] is built around the college football team.',
#   'subArgument': 'Some large universities [21] do not have college football teams, yet still provide an American college experience.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'A lot of the typical American college experience [20] is built around the college football team.',
#   'subArgument': 'Many schools have community based events like tailgates [22] and parties before or after football games, which are essential for the enjoyment of students and their college experience.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Many schools have community based events like tailgates [22] and parties before or after football games, which are essential for the enjoyment of students and their college experience.',
#   'subArgument': 'Tailgating is associated [23] with excessive drinking and other dangerous activities.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 5,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'A lot of the typical American college experience [20] is built around the college football team.',
#   'subArgument': 'Interuniversity football rivalries [24] form the core identity of many colleges.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'College football programs contribute significantly to the identity and brand of universities in the United States.',
#   'subArgument': 'A connection to the college football team can build strong alumni networks [25] that continue to support the college after graduation.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'College football programs contribute significantly to the identity and brand of universities in the United States.',
#   'subArgument': 'Many colleges center their homecoming celebration [26] around a football game.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'College football programs contribute significantly to the identity and brand of universities in the United States.',
#   'subArgument': 'While it is true that football programs are core to the identity of many universities [27], this connection is not necessary and can be severed.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'While it is true that football programs are core to the identity of many universities [27], this connection is not necessary and can be severed.',
#   'subArgument': 'Severing the connection between a football program and the college experience can fail. For example, University of Alabama at Birmingham reinstated [28] football shortly after dropping it.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Severing the connection between a football program and the college experience can fail. For example, University of Alabama at Birmingham reinstated [28] football shortly after dropping it.',
#   'subArgument': 'Importantly, the football program at Alabama Birmingham was dropped for political and financial reasons, and not for moral ones.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 5,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'While it is true that football programs are core to the identity of many universities [27], this connection is not necessary and can be severed.',
#   'subArgument': 'Decoupling football programs from college identity would fundamentally change the college experience, making it less fulfilling for many students.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Decoupling football programs from college identity would fundamentally change the college experience, making it less fulfilling for many students.',
#   'subArgument': 'Saying that decoupling football programs from college identity would fundamentally change the college experience overstates the impact on the college experience.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 5,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Saying that decoupling football programs from college identity would fundamentally change the college experience overstates the impact on the college experience.',
#   'subArgument': 'College football attendance is declining [29].',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 6,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'While it is true that football programs are core to the identity of many universities [27], this connection is not necessary and can be severed.',
#   'subArgument': 'In 1901, the MIT student body voted 119-117 to discontinue [30] the intercollegiate football squad.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'In 1901, the MIT student body voted 119-117 to discontinue [30] the intercollegiate football squad.',
#   'subArgument': 'In 1978, a group of students self-organized to re-establish [31] the MIT team.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 5,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'College football programs contribute significantly to the identity and brand of universities in the United States.',
#   'subArgument': 'University mission statements that define the core identity of the university do not mention football. This is true even for universities that are famous for their football programs.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'University mission statements that define the core identity of the university do not mention football. This is true even for universities that are famous for their football programs.',
#   'subArgument': 'The University of Alabama [32]\'s mission statement puts emphasis "...on quality programs in the areas of teaching, research and service" without mentioning football.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'University mission statements that define the core identity of the university do not mention football. This is true even for universities that are famous for their football programs.',
#   'subArgument': 'The mission of the University of Oklahoma [33] is to provide the best possible educational experience. This has no relationship to football.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'University mission statements that define the core identity of the university do not mention football. This is true even for universities that are famous for their football programs.',
#   'subArgument': "The Ohio State University's core values [34] do not include football or competitive sports.",
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'University mission statements that define the core identity of the university do not mention football. This is true even for universities that are famous for their football programs.',
#   'subArgument': 'Mission statements at universities often present and articulate a world view that is narrow, shallow, irrelevant and devoid of meaning [35].',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'College football programs contribute significantly to the identity and brand of universities in the United States.',
#   'subArgument': 'College football is the main source of entertainment [36] in many small towns.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Football is very popular and a critical part of many communities.',
#   'subArgument': 'Professional football organizations contribute to the identity of the cities and states that they affiliated with.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 2,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Professional football organizations contribute to the identity of the cities and states that they affiliated with.',
#   'subArgument': 'Professional football organizations shape [37], and are shaped by [38], the culture of the city they are based in.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Professional football organizations contribute to the identity of the cities and states that they affiliated with.',
#   'subArgument': "Celebrations after the Philadelphia Eagles' 2018 Super Bowl [39] victory disintegrated into rioting and looting, ultimately costing the city thousands of dollars in damages.",
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Football is very popular and a critical part of many communities.',
#   'subArgument': 'Communities are capable of changing, and can support other sports or cultural activities.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 2,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Communities are capable of changing, and can support other sports or cultural activities.',
#   'subArgument': 'There are long traditions supporting baseball [40] and basketball [41] in many communities, and this could be shared with new communities.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Football is very popular and a critical part of many communities.',
#   'subArgument': 'High school football programs are important for small towns and communities.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 2,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'High school football programs are important for small towns and communities.',
#   'subArgument': 'Student athletes playing for a high school team represent the communities [42] they live in. This inspires a sense of honor and responsibility to perform well and come together as a team.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Student athletes playing for a high school team represent the communities [42] they live in. This inspires a sense of honor and responsibility to perform well and come together as a team.',
#   'subArgument': 'Camaraderie and togetherness are the most prevalent in competitions against rival schools. Rivalries [43] are often built upon long traditions that give players a sense of being a part of something greater than themselves.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'High school football programs are important for small towns and communities.',
#   'subArgument': 'High school football programs are associated with harmful things like hazing and aggression.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'High school football programs are associated with harmful things like hazing and aggression.',
#   'subArgument': 'A national hazing [44] scandal originated from New Jersey in 2014, "where six players accused of sexually brutalizing former teammates were sentenced to 50 hours of community service."',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'High school football programs are associated with harmful things like hazing and aggression.',
#   'subArgument': 'In 2015, a group of parents of players in Southern California forcibly entered a high school locker room in order to attack students in retaliation [45] for an incident in a football game.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'High school football programs are associated with harmful things like hazing and aggression.',
#   'subArgument': 'High school football is more beneficial than harmful.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'High school football is more beneficial than harmful.',
#   'subArgument': 'High school football improves the educational opportunities of student athletes.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 5,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'High school football improves the educational opportunities of student athletes.',
#   'subArgument': 'High school varsity and junior varsity student athletes tend to get lower English and history grades [46] during active sports seasons.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 6,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'High school football improves the educational opportunities of student athletes.',
#   'subArgument': 'Some student athletes who might otherwise have dropped out [47] of high school stay in school instead and graduate because of football.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 6,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'High school football improves the educational opportunities of student athletes.',
#   'subArgument': 'High school football enables athletes to compete for scholarships [48] that could give them a great college education.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 6,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'High school football is more beneficial than harmful.',
#   'subArgument': 'High school football programs are uniquely ill-equipped [49] to manage the health risks associated with playing the game.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 5,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'High school football programs are uniquely ill-equipped [49] to manage the health risks associated with playing the game.',
#   'subArgument': 'High school athletic programs often lack certified athletic trainers capable of advising students when to take breaks or continue playing.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 6,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'High school athletic programs often lack certified athletic trainers capable of advising students when to take breaks or continue playing.',
#   'subArgument': 'There was no certified athletic trainer present at Coahoma County High School to prevent Dennis Mitchell [50] from re-entering the game after taking a hard hit and vomiting. He later collapsed on the field and died as a result.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 7,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'High school football programs are uniquely ill-equipped [49] to manage the health risks associated with playing the game.',
#   'subArgument': 'Rather than banning high school football programs, they should be reformed and given additional funding to deal with any health problems that arise.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 6,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'High school football is more beneficial than harmful.',
#   'subArgument': 'It is difficult [51] to weigh the harm of football for a young athlete against the benefits, given that the potential for long-term harm varies.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 5,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'High school football is more beneficial than harmful.',
#   'subArgument': 'High school football gives young kids lessons [52] in teamwork, hard work, and sportsmanship that they otherwise would not learn in classrooms.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 5,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'High school football gives young kids lessons [52] in teamwork, hard work, and sportsmanship that they otherwise would not learn in classrooms.',
#   'subArgument': 'Evidence suggests that character building [53] and good judgment follow from participation in music, theater, and community service programs, but not from participation in sports.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 6,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'High school football gives young kids lessons [52] in teamwork, hard work, and sportsmanship that they otherwise would not learn in classrooms.',
#   'subArgument': 'High school football teams help discover and hone athletic talents in students who would otherwise go untrained.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 6,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'High school football is more beneficial than harmful.',
#   'subArgument': "High school football is good for students who are not directly involved with their school's team.",
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 5,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': "High school football is good for students who are not directly involved with their school's team.",
#   'subArgument': 'Students go to games together, cheer their team on together and follow their teams to away games. This strengthens relationships and builds a unique sense of camaraderie.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 6,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': "High school football is good for students who are not directly involved with their school's team.",
#   'subArgument': 'Passion for high school football forms a culture that is inherently exclusionary to the students who do not want to follow the sport.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 6,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Passion for high school football forms a culture that is inherently exclusionary to the students who do not want to follow the sport.',
#   'subArgument': 'The exclusionary culture of football is not specific to football. It can surround any competitive high school sport or extra curricular activity.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 7,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'American football is too dangerous to permit league football.',
#   'subArgument': 'Traumatic brain and spinal injuries are more common in football than in any other sport.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 2,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Traumatic brain and spinal injuries are more common in football than in any other sport.',
#   'subArgument': 'A 1994 study found that spinal cord injuries are most common [54] in swimming and gymnastics, rather than American football.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'A 1994 study found that spinal cord injuries are most common [54] in swimming and gymnastics, rather than American football.',
#   'subArgument': 'Nearly [55] 51% of sports-related spinal cord injuries that were recorded occurred while swimming.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'A 1994 study found that spinal cord injuries are most common [54] in swimming and gymnastics, rather than American football.',
#   'subArgument': 'The 1994 [56] study is based on a very small and non-representative sample population (N = 31), and thus the results should not be generalized.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Traumatic brain and spinal injuries are more common in football than in any other sport.',
#   'subArgument': 'Football players are at risk of catastrophic [57] spinal cord injuries, which are significant life-changing events and can sometimes result in death.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Football players are at risk of catastrophic [57] spinal cord injuries, which are significant life-changing events and can sometimes result in death.',
#   'subArgument': "Darryl Stingley [58]'s career as a receiver for the New England Patriots was cut short because of a head-on collision with Oakland Raider safety Jack Tatum, rendering him paralyzed from the neck down.",
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Football players are at risk of catastrophic [57] spinal cord injuries, which are significant life-changing events and can sometimes result in death.',
#   'subArgument': 'Catastrophic injuries are increasingly rare [59] in American football, with deaths caused directly by football significantly declining over the decades.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Traumatic brain and spinal injuries are more common in football than in any other sport.',
#   'subArgument': 'Football is associated with chronic traumatic encephalopathy [60] (CTE), which is a neurodegenerative disease found in people with multiple head injuries that typically entails behavioral, emotional, and cognitive difficulties.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Football is associated with chronic traumatic encephalopathy [60] (CTE), which is a neurodegenerative disease found in people with multiple head injuries that typically entails behavioral, emotional, and cognitive difficulties.',
#   'subArgument': 'The long term effects of multiple head injuries, including whether it leads to CTE, have still not been explored [61] sufficiently to establish that there is a causal link.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Football is associated with chronic traumatic encephalopathy [60] (CTE), which is a neurodegenerative disease found in people with multiple head injuries that typically entails behavioral, emotional, and cognitive difficulties.',
#   'subArgument': 'One large study [62] found that 110 out of 111 (99%) deceased NFL players had chronic traumatic encephalopathy.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'One large study [62] found that 110 out of 111 (99%) deceased NFL players had chronic traumatic encephalopathy.',
#   'subArgument': 'The sample that showed widespread chronic traumatic encephalopathy (CTE) suffered from selection bias [63]. The players who donated their brains to the study were the ones experiencing cognitive issues.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 5,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Football is associated with chronic traumatic encephalopathy [60] (CTE), which is a neurodegenerative disease found in people with multiple head injuries that typically entails behavioral, emotional, and cognitive difficulties.',
#   'subArgument': 'The rate of depression [64] for former football players who suffered from concussions is much higher than for other former athletes.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Traumatic brain and spinal injuries are more common in football than in any other sport.',
#   'subArgument': 'In the United States, severe head injuries in sports are most commonly associated [65] with American football, and a reported 90% of cases are acute subdural hematomas (ASDH).',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'In the United States, severe head injuries in sports are most commonly associated [65] with American football, and a reported 90% of cases are acute subdural hematomas (ASDH).',
#   'subArgument': 'In 2009, the number of estimated head injuries for cycling was nearly double [66] the head injuries associated with football.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'In the United States, severe head injuries in sports are most commonly associated [65] with American football, and a reported 90% of cases are acute subdural hematomas (ASDH).',
#   'subArgument': 'The number of cases of ASDH is increasing [67] annually.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'In the United States, severe head injuries in sports are most commonly associated [65] with American football, and a reported 90% of cases are acute subdural hematomas (ASDH).',
#   'subArgument': 'In the United States, almost all patients with ASDH due to sport-related head injuries are senior high school students or younger [68].',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Traumatic brain and spinal injuries are more common in football than in any other sport.',
#   'subArgument': 'Severe head injuries are prevalent in many other [69] contact sports such as rugby, boxing, judo, ice hockey, skiing, and snowboarding.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'American football is too dangerous to permit league football.',
#   'subArgument': 'American football is a contact sport that results in acute injuries that harm players over their lifetime.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 2,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'American football is a contact sport that results in acute injuries that harm players over their lifetime.',
#   'subArgument': 'Minor injuries and concussions are common in American Football.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Minor injuries and concussions are common in American Football.',
#   'subArgument': 'Concussions are common [70] in professional American Football.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Minor injuries and concussions are common in American Football.',
#   'subArgument': 'The 2012 [71] and 2016 [72] International Conferences on Concussion in Sports found that the data connecting repeated concussions and long-term health issues is inconclusive.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The 2012 [71] and 2016 [72] International Conferences on Concussion in Sports found that the data connecting repeated concussions and long-term health issues is inconclusive.',
#   'subArgument': 'Even if the literature on long-term consequences is inconclusive, this does not mean that there is no evidence of long-term consequences.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 5,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'American football is a contact sport that results in acute injuries that harm players over their lifetime.',
#   'subArgument': 'The grueling nature of the sport includes constant high intensity practice which can become dangerous [73] for football players.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 3,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'The grueling nature of the sport includes constant high intensity practice which can become dangerous [73] for football players.',
#   'subArgument': 'Football players are capable of great feats of strength [74] and athleticism as a result of the intensity of football practice and competition.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The grueling nature of the sport includes constant high intensity practice which can become dangerous [73] for football players.',
#   'subArgument': 'Football leagues could reduce [75] the number of heat-related issues by limiting the number of games and practices during hot and humid times of the year.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The grueling nature of the sport includes constant high intensity practice which can become dangerous [73] for football players.',
#   'subArgument': 'Football programs could reduce the exposure of players to dangerous temperatures by investing in enclosed [76] stadiums and indoor practice facilities.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The grueling nature of the sport includes constant high intensity practice which can become dangerous [73] for football players.',
#   'subArgument': 'Football players often have to use dangerous amounts of painkillers [77] simply to survive the season.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'The grueling nature of the sport includes constant high intensity practice which can become dangerous [73] for football players.',
#   'subArgument': 'On average, former NFL players (even relatively young former players) have disproportionately [78] high levels of whole-person impairment (WPI) due to muscular-skeletal damage.',
#   'subject': 'Should American Football Be Banned?',
#   'subArgumentLevel': 4,
#   'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'On average, former NFL players (even relatively young former players) have disproportionately [78] high levels of whole-person impairment (WPI) due to muscular-skeletal damage.',
#   'subArgument': 'Professional players lose, on average, three years [79] of life expectancy for every year they play professional football.',
# ...
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 7,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'The state would be a fertile ground for domination by the global rich.',
#   'subArgument': '-> See 1.5.1.1.7.2.1.3.1.2.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 7,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'The state would be a fertile ground for domination by the global rich.',
#   'subArgument': 'The rich are able to manipulate [379] governments and economies through bribes and close ties with those at the top. In a one world state where organisations would grow in scale, it would become much harder to bribe those institutions or use nepotism to influence their decisions.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 7,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The state would be a fertile ground for domination by the global rich.',
#   'subArgument': 'It is likely that there will be rifts among rich individuals and lobbies from all around the world in their attempts to influence politics of a one world state. This would make elite capture difficult and more fractious.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 7,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The one world state would likely be dominated by the interests of powerful actors.',
#   'subArgument': 'This state is likely be dominated by the interests of the most powerful religion.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 6,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'This state is likely be dominated by the interests of the most powerful religion.',
#   'subArgument': 'Christianity is the most powerful religion, and so would be likely able to influence the one world state far more than other faiths.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 7,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Christianity is the most powerful religion, and so would be likely able to influence the one world state far more than other faiths.',
#   'subArgument': 'Christianity holds far more wealth than other religions, which may mean that it is more easily able to dominate in a one world state context.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 8,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Christianity holds far more wealth than other religions, which may mean that it is more easily able to dominate in a one world state context.',
#   'subArgument': "A 2015 study found that more than half [380] of the world's millionaires identify as Christians.",
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 9,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Christianity holds far more wealth than other religions, which may mean that it is more easily able to dominate in a one world state context.',
#   'subArgument': 'A report attributed 55% [381] of worldwide wealth to Christians.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 9,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Christianity holds far more wealth than other religions, which may mean that it is more easily able to dominate in a one world state context.',
#   'subArgument': 'According to a large 2014 study, American Jews [382] are the most likely to live in a household with a total income of $100,000 or more.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 9,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Christianity is the most powerful religion, and so would be likely able to influence the one world state far more than other faiths.',
#   'subArgument': 'Christianity has numerous denominations [383], many of which have a history of conflict [384] with each other. This lack of cohesion makes it unlikely that Christianity would be the most powerful religion in a one world state.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 8,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Christianity has numerous denominations [383], many of which have a history of conflict [384] with each other. This lack of cohesion makes it unlikely that Christianity would be the most powerful religion in a one world state.',
#   'subArgument': '-> See 1.3.1.1.1.2.1.1.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 9,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Christianity is the most powerful religion, and so would be likely able to influence the one world state far more than other faiths.',
#   'subArgument': 'Christianity, which has about 2.4 billion [385] followers, is likely to influence the policies of the one world state.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 8,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Christianity, which has about 2.4 billion [385] followers, is likely to influence the policies of the one world state.',
#   'subArgument': 'The population of Muslims around the world is growing at a fast pace, and Islam is expected to be the largest religion in the world by 2070 [386]. This indicates that there is a rise of other influential religions that will cut down the influence of Christianity over the policies of the one world state.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 9,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The population of Muslims around the world is growing at a fast pace, and Islam is expected to be the largest religion in the world by 2070 [386]. This indicates that there is a rise of other influential religions that will cut down the influence of Christianity over the policies of the one world state.',
#   'subArgument': 'Islamophobia is significantly more common [387] than Christophobia. Thus, even if the population of Muslims grows, this does not necessarily indicate that its influence will surpass that of Christianity.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 10,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'Islamophobia is significantly more common [387] than Christophobia. Thus, even if the population of Muslims grows, this does not necessarily indicate that its influence will surpass that of Christianity.',
#   'subArgument': 'According to a 2014 Pew Research Center survey [388], US citizens have colder, more negative views about Muslims than they have about any other religious group.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 11,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'The population of Muslims around the world is growing at a fast pace, and Islam is expected to be the largest religion in the world by 2070 [386]. This indicates that there is a rise of other influential religions that will cut down the influence of Christianity over the policies of the one world state.',
#   'subArgument': 'The two main factions of Islam, Sunni and Shia, have a 1400-year-old [389] history of conflict that has become extremely violent [390] in some areas of the world. This power struggle would likely weaken the influence that the religion as a whole could have over other religions, regardless of absolute numbers of followers.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 10,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The population of Muslims around the world is growing at a fast pace, and Islam is expected to be the largest religion in the world by 2070 [386]. This indicates that there is a rise of other influential religions that will cut down the influence of Christianity over the policies of the one world state.',
#   'subArgument': "US-based Pew Research Centre [391] analysed demographic change among the world's major religions, and found that the world's population of Muslims will grow by 73 per cent between 2010 and 2050, compared to 35 per cent for Christians, while the overall population of the world will grow by 37 per cent over the same period.",
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 10,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'The population of Muslims around the world is growing at a fast pace, and Islam is expected to be the largest religion in the world by 2070 [386]. This indicates that there is a rise of other influential religions that will cut down the influence of Christianity over the policies of the one world state.',
#   'subArgument': 'Muslims also have various demographic factors [392] (female fertility rate, youngest median age, concentration in high population growth regions) in their favor that continue to contribute to their fast growth.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 10,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Christianity, which has about 2.4 billion [385] followers, is likely to influence the policies of the one world state.',
#   'subArgument': 'This influence will be undermined by religious switching [393], which is expected to hinder the growth of Christians by an estimated 72 million followers between 2015 and 2060.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 9,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'This state is likely be dominated by the interests of the most powerful religion.',
#   'subArgument': '-> See 1.3.2.3.4.1.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 7,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'This state is likely be dominated by the interests of the most powerful religion.',
#   'subArgument': 'As long as the state maintained a strict legal separation of church and state (as many states [394] do currently), no religious group could substantially influence politics.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 7,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The one world state would likely be dominated by the interests of powerful actors.',
#   'subArgument': 'All states are dominated by interest groups. This is not a problem unique to the one world state.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 6,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'All states are dominated by interest groups. This is not a problem unique to the one world state.',
#   'subArgument': 'This problem does not need to be unique to a one world state to serve as a rebuttal to the idea that the world state would fix global inequalities.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 7,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'All states are dominated by interest groups. This is not a problem unique to the one world state.',
#   'subArgument': 'The USA is known [395] for its interest group culture: the multi-layered federal structure of the US government allows for multiple points of access to law-makers by countless interest groups and their lobbyists, meaning these can have a large influence on national policy.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 7,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'The one world state would likely be dominated by the interests of powerful actors.',
#   'subArgument': '-> See 1.3.2.2.2.1.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 6,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  {'topArgument': 'The one world state would likely be dominated by the interests of powerful actors.',
#   'subArgument': 'The creation of a one world state could empower large international corporations by allowing them to ignore domestic regulations. This could lead to a concentration in power among a few companies, and a resulting increase in inequality.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 6,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'The creation of a one world state could empower large international corporations by allowing them to ignore domestic regulations. This could lead to a concentration in power among a few companies, and a resulting increase in inequality.',
#   'subArgument': 'National governments already [396] frequently undertax large international corporations, leading to the underfunding of vital public services and disproportionately impacting the poorest. If the few domestic regulations in place to reduce this were removed with the advent of the one world state, it would likely become an even larger-scale issue.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 7,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'Even if there are strong links between social ills and inequality, a one world state will not fix inequality.',
#   'subArgument': 'The one world state would likely oppress those with marginalised identities.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 5,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': False,
#   'isSupport': True},
#  {'topArgument': 'The one world state would likely oppress those with marginalised identities.',
#   'subArgument': 'Unlike in individual countries, this state would have a number of large minority racial groups, with no one group constituting the overwhelming majority [397] of the population. Such a state is less likely to be structurally racist, as power would be distributed amongst groups.',
#   'subject': 'Should there be One World State?',
#   'subArgumentLevel': 6,
#   'domain': "['States', 'Nations', 'Culture', 'Economics', 'Politics']",
#   'isAttack': True,
#   'isSupport': False},
#  ...]

# %%
pairs[0]
# Out:
# {'topArgument': 'Football is very popular and a critical part of many communities.',
#  'subArgument': 'The institution of American football alienates many communities.',
#  'subject': 'Should American Football Be Banned?',
#  'subArgumentLevel': 2,
#  'domain': "['Sports', 'USA', 'Football', 'American_Football', 'Entertainment']",
#  'isAttack': True,
#  'isSupport': False}

# %%
argSrc = [x["subArgument"] for x in pairs]
argTrg = [x["topArgument"] for x in pairs]
datasetSource = ["kialo" for x in pairs]
topic = [x["domain"] for x in pairs]
relations = ["attack" if x["isAttack"] else "support" for x in pairs]

d = pd.DataFrame.from_dict({
  "topic": topic,
  "argSrc" : argSrc,
  "argTrg" : argTrg,
  "relation" : relations
})

d
# Out:
#                                                    topic  \
# 0      ['Sports', 'USA', 'Football', 'American_Footba...
# 1      ['Sports', 'USA', 'Football', 'American_Footba...
# 2      ['Sports', 'USA', 'Football', 'American_Footba...
# 3      ['Sports', 'USA', 'Football', 'American_Footba...
# 4      ['Sports', 'USA', 'Football', 'American_Footba...
# ...                                                  ...
# 53517  ['Environment', 'Health', 'Policy', 'Government']
# 53518  ['Environment', 'Health', 'Policy', 'Government']
# 53519  ['Environment', 'Health', 'Policy', 'Government']
# 53520  ['Environment', 'Health', 'Policy', 'Government']
# 53521  ['Environment', 'Health', 'Policy', 'Government']
#
#                                                   argSrc  \
# 0      The institution of American football alienates...
# 1      The institution of American football promotes ...
# 2      American football promotes a form of masculini...
# 3      Jim Harbaugh [2] and Rush Limbaugh [3] argue t...
# 4      A player formerly coached by Jim Harbauge [4] ...
# ...                                                  ...
# 53517  In 2020, 72.7% of the US population on communi...
# 53518  Hong Kong and Singapore both have 100% of thei...
# 53519  Fluoridated water acts as a systemic preventiv...
# 53520  Fluoridated water is considered as pharmacolog...
# 53521  Community water fluoridation is one of the mos...
#
#                                                   argTrg relation
# 0      Football is very popular and a critical part o...   attack
# 1      The institution of American football alienates...  support
# 2      The institution of American football promotes ...  support
# 3      American football promotes a form of masculini...   attack
# 4      Jim Harbaugh [2] and Rush Limbaugh [3] argue t...   attack
# ...                                                  ...      ...
# 53517  Despite the available alternatives, fluoridati...  support
# 53518  Despite the available alternatives, fluoridati...  support
# 53519  Alternatives to fluoridated water and promotin...   attack
# 53520  Fluoridated water acts as a systemic preventiv...   attack
# 53521  Fluoridated water acts as a systemic preventiv...  support
#
# [53522 rows x 4 columns]

# %%
d_filtered = d[~d["argSrc"].str.contains(r'See \d+(\.\d+)*')]
print(d_filtered.shape)
d_filtered.to_csv("../../data/kialoPairsEnglist.csv")
# Out:
# C:\Users\emili\AppData\Local\Temp\ipykernel_23592\3666154035.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   d_filtered = d[~d["argSrc"].str.contains(r'See \d+(\.\d+)*')]
# (51249, 4)
